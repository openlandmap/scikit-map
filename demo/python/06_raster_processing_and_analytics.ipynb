# %% [markdown]
# # PyEumap - Raster Processing and Analytics
#
# This tutorial will explain the usage of classes from `pyeumap.analytics` for analysis of raster data within a bounding geometry.
#
# First we will grab the bounding geometry of Plitvice Lakes National Park in Croatia and define a raster path (url) which will be used both as the reference raster for `RasterReader` and in further analysis. For this purpose we will use the GeoHarmonizer landcover data for 2019.

# %%
from pyeumap.misc import ttprint
from pyeumap.analytics import RasterReader, RasterAggregator, RasterWriter
import requests
import json
import numpy as np
from pyeumap import plotter

geojson = requests.get('http://amdtr.multione.hr:1300/plitvice.geojson').text
geom = json.loads(geojson)['features'][0]['geometry']
fp = 'https://s3.eu-central-1.wasabisys.com/eumap/lcv/lcv_landcover.hcl_lucas.corine.rf_p_30m_0..0cm_2019_eumap_epsg3035_v0.1.tif'

# %% [markdown]
# Next, we will initialize our reader, which serves to optimize block-by-block reading of large rasters. For large files this might take a few seconds.

# %%
ttprint('initializing reader')

reader = RasterReader(fp)

ttprint('reader initialized')
# Out:
# [13:18:48] initializing reader
# [13:18:50] reader initialized

# %% [markdown]
# ## Aggregation of values within a bounding geometry
#
# Now we can initialize our `RasterAggregator`, define a function that calculates the area of all pixels corresponding to _urban fabric_ and run it across the bounding geometry.
#
# The processing function can produce pixel-wise results, as the `agg` will take care of sumation.
#
# Furthermore, when doing this we can choose to omit the geometry mask, which causes the function to be run accross all raster blocks which touch the bounding geometry. This provides a speedup for large geometries but can also produce very different results.

# %%
agg = RasterAggregator(reader)

def urban_fabric_area(lc):
    return (lc==1) * 9e-4 # spatial resolution is 30x30 m

ttprint('aggregating with geometry mask')

result = agg.aggregate(
    fp, geom,
    block_func=urban_fabric_area,
    agg_func=np.sum,
)

ttprint('result:', result, 'km2')

ttprint('aggregating without geometry mask')

result = agg.aggregate(
    fp, geom,
    block_func=urban_fabric_area,
    agg_func=np.sum,
    geometry_mask=False,
)

ttprint('result:', result, 'km2')
# Out:
# [13:18:50] aggregating with geometry mask
# reader using 3 threads
# [13:18:51] result: 0.4698 km2
# [13:18:51] aggregating without geometry mask
# reader using 3 threads
# [13:18:51] result: 22.581000000000007 km2

# %% [markdown]
# ## Producing processed raster output within a bounding geometry
#
# Next, we will produce a mask of all pixels that correspond to _urban fabric_ within our geometry. As above, we can omit the geometry mask for faster, but different, results. We will show the results using `pyeumap.plotter`.

# %%
def is_urban_fabric(lc):
    return lc == 1

writer = RasterWriter(reader)

ttprint('writing with geometry mask')
writer.write(fp, 'ndvi_mask.tif', geom, is_urban_fabric, dtype='uint8', nodata=0)

ttprint('done')

plotter.plot_rasters(
    'urban_fabric_mask.tif',
    cmaps='Reds',
    figsize=6,
)

ttprint('writing without geometry mask')
writer.write(fp, 'urban_fabric_nomask.tif', geom, is_urban_fabric, geometry_mask=False, dtype='uint8', nodata=0)

ttprint('done')

plotter.plot_rasters(
    'urban_fabric_nomask.tif',
    cmaps='Reds',
    figsize=6,
)
# Out:
# [13:18:51] writing with geometry mask
# reader using 3 threads
# [13:18:51] done
# [13:18:51] writing without geometry mask
# reader using 3 threads
# [13:18:52] done

# %% [markdown]
# We can also process an arbitrary number of rasters at the same time. To demonstrate this, we will calculate NDVI within the bounding geometry using the red and NIR LANDSAT bands.

# %%
def ndvi(red, nir):
    return (nir - red) / (nir + red)

fp = [
    'http://s3.eu-central-1.wasabisys.com/eumap/landsat/landsat_ard_20180625_20180912_red_p50.tif',
    'http://s3.eu-central-1.wasabisys.com/eumap/landsat/landsat_ard_20180625_20180912_nir_p50.tif',
]

ttprint('writing with geometry mask')
writer.write(fp, 'ndvi_mask.tif', geom, ndvi, dtype='float32', nodata=-9999)

ttprint('done')

plotter.plot_rasters(
    'ndvi_mask.tif',
    cmaps='Greens',
    figsize=6,
    vmin=-1,
    vmax=1,
)

ttprint('writing without geometry mask')
writer.write(fp, 'ndvi_nomask.tif', geom, ndvi, geometry_mask=False, dtype='float32', nodata=-9999)

ttprint('done')

plotter.plot_rasters(
    'ndvi_nomask.tif',
    cmaps='Greens',
    figsize=6,
    vmin=-1,
    vmax=1,
)
# Out:
# [13:18:52] writing with geometry mask
# reader using 3 threads
# [13:18:55] done
# [13:18:56] writing without geometry mask
# reader using 3 threads
# [13:18:58] done
